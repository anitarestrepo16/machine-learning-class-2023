# %% [markdown]
# # Lab 6: Mini Project 3
#
# Click [here](https://code.datasciencedojo.com/datasciencedojo/datasets/tree/master/Bike%20Sharing) for Data Dictionary

# %% [markdown]
# Predicting bike rental count based on environmental and seasonal settings.
#
# Qs. What affects bike rentals?
#
# Qs. How could we predict?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
import seaborn as sns
sns.set()
sns.set_style("darkgrid")
import warnings
warnings.filterwarnings("ignore")
import math
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold

# %%
# Helps to display all rows and columns in pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("bike.csv")

# %%
print(data.shape)
data.head()
# Out:
# (17379, 17)
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# Season (1:   springer, 2: summer, 3: fall, 4: winter)
#
#
# Year (0: 2011,   1:2012)
#
#
# Weather Situation (1: Clear, Few   clouds, Partly cloudy, Partly cloudy; 2: Mist + Cloudy, Mist + Broken clouds,   Mist + Few clouds, Mist; 3: Light Snow, Light Rain + Thunderstorm + Scattered   clouds, Light Rain + Scattered clouds, 4: Heavy Rain + Ice Pallets +   Thunderstorm + Mist, Snow + Fog)
#
# Date (Format: YYYY-MM-DD)

# %%
data.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
# Set attribute 'instant' as index
data.set_index(['instant'], inplace = True)
data.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Removing dteday, casual and registered columns.
# Casual + Registered = Total 

temp_df = data.copy()

data.drop(['dteday', 'casual','registered'], axis=1, inplace=True)

# %% [markdown]
# Qs. Why remove dteday?

# %%
# demo of how to extract features using datetime module 

import datetime as dt 

temp_df.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %%
temp_df['dteday'] = pd.to_datetime(temp_df['dteday'])
temp_df.dtypes
# Out:
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
# extract datetime features from the datetime column 

# year
temp_df['year'] = temp_df['dteday'].dt.year

# month 
temp_df['month'] = temp_df['dteday'].dt.month

# day of month
temp_df['dayofmonth'] = temp_df['dteday'].dt.day

# day of year 
temp_df['dayofyear'] = temp_df['dteday'].dt.dayofyear

# day of week 
temp_df['day_of_week'] = temp_df['dteday'].dt.dayofweek

temp_df.head()

# Can have hour of the day as well if we have a datetime column with time too. 


# Look into datetime module. Very useful for time series feature engineering
# Out:
#             dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1       2011-01-01       1   0     1   0        0        6           0
# 2       2011-01-01       1   0     1   1        0        6           0
# 3       2011-01-01       1   0     1   2        0        6           0
# 4       2011-01-01       1   0     1   3        0        6           0
# 5       2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1
#
#          year  month  dayofmonth  dayofyear  day_of_week
# instant
# 1        2011      1           1          1            5
# 2        2011      1           1          1            5
# 3        2011      1           1          1            5
# 4        2011      1           1          1            5
# 5        2011      1           1          1            5

# %%
# checking for null values 


data.isnull().sum()
# Out:
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64

# %%
# we're predicting the variable 'cnt' or count
X = data.copy()
y = X.pop('cnt') 

# pop will remove the last element from a list if called without any parameter. 
# It returns the value "popped"

# %%
# Mapping values. Look at the data dictionary
seasons = {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"}
data["season"].replace(seasons, inplace=True)
data.head()
# Out:
#          season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# instant
# 1        Spring   0     1   0        0        6           0           1  0.24
# 2        Spring   0     1   1        0        6           0           1  0.22
# 3        Spring   0     1   2        0        6           0           1  0.22
# 4        Spring   0     1   3        0        6           0           1  0.24
# 5        Spring   0     1   4        0        6           0           1  0.24
#
#           atemp   hum  windspeed  cnt
# instant
# 1        0.2879  0.81        0.0   16
# 2        0.2727  0.80        0.0   40
# 3        0.2727  0.80        0.0   32
# 4        0.2879  0.75        0.0   13
# 5        0.2879  0.75        0.0    1

# %%
X.head()
# Out:
#          season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# instant
# 1             1   0     1   0        0        6           0           1  0.24
# 2             1   0     1   1        0        6           0           1  0.22
# 3             1   0     1   2        0        6           0           1  0.22
# 4             1   0     1   3        0        6           0           1  0.24
# 5             1   0     1   4        0        6           0           1  0.24
#
#           atemp   hum  windspeed
# instant
# 1        0.2879  0.81        0.0
# 2        0.2727  0.80        0.0
# 3        0.2727  0.80        0.0
# 4        0.2879  0.75        0.0
# 5        0.2879  0.75        0.0

# %%
# Make dummies
# One-hot encoding using python's built-in get_dummies function. 


# https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html

X = pd.get_dummies(X, columns = ['season'])
X.head()


# drop_first = True to get k-1 variables
# Out:
#          yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# instant
# 1         0     1   0        0        6           0           1  0.24  0.2879
# 2         0     1   1        0        6           0           1  0.22  0.2727
# 3         0     1   2        0        6           0           1  0.22  0.2727
# 4         0     1   3        0        6           0           1  0.24  0.2879
# 5         0     1   4        0        6           0           1  0.24  0.2879
#
#           hum  windspeed  season_1  season_2  season_3  season_4
# instant
# 1        0.81        0.0         1         0         0         0
# 2        0.80        0.0         1         0         0         0
# 3        0.80        0.0         1         0         0         0
# 4        0.75        0.0         1         0         0         0
# 5        0.75        0.0         1         0         0         0

# %%
# Summary statistics

X.describe()
# Out:
#                  yr          mnth            hr       holiday       weekday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.502561      6.537775     11.546752      0.028770      3.003683
# std        0.500008      3.438776      6.914405      0.167165      2.005771
# min        0.000000      1.000000      0.000000      0.000000      0.000000
# 25%        0.000000      4.000000      6.000000      0.000000      1.000000
# 50%        1.000000      7.000000     12.000000      0.000000      3.000000
# 75%        1.000000     10.000000     18.000000      0.000000      5.000000
# max        1.000000     12.000000     23.000000      1.000000      6.000000
#
#          workingday    weathersit          temp         atemp           hum  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.682721      1.425283      0.496987      0.475775      0.627229
# std        0.465431      0.639357      0.192556      0.171850      0.192930
# min        0.000000      1.000000      0.020000      0.000000      0.000000
# 25%        0.000000      1.000000      0.340000      0.333300      0.480000
# 50%        1.000000      1.000000      0.500000      0.484800      0.630000
# 75%        1.000000      2.000000      0.660000      0.621200      0.780000
# max        1.000000      4.000000      1.000000      1.000000      1.000000
#
#           windspeed      season_1      season_2      season_3      season_4
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.190098      0.244088      0.253697      0.258703      0.243512
# std        0.122340      0.429557      0.435139      0.437935      0.429214
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.104500      0.000000      0.000000      0.000000      0.000000
# 50%        0.194000      0.000000      0.000000      0.000000      0.000000
# 75%        0.253700      0.000000      1.000000      1.000000      0.000000
# max        0.850700      1.000000      1.000000      1.000000      1.000000

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# set random state to 25 in the mini-project

# %% [markdown]
# ## Modeling

# %%
#5

from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
print(reg.score(X_train, y_train))
print(reg.score(X_test, y_test))
# Out:
# 0.4010729752022212
# 0.3776077652721129

# %%
from sklearn.metrics import mean_squared_error
y_pred = reg.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 20569.60788906485

# %% [markdown]
# ## Lasso, Ridge

# %% [markdown]
# Regularization techniques.
#
# - reduce model complexity
# - prevent overfitting
# - add a penalty for adding too many predictors

# %%
# Refer to https://scikit-learn.org/stable/auto_examples/linear_model/plot_lasso_model_selection.html
# Optimizing lasso hyperparameter through AIC
from sklearn.linear_model import LassoLarsIC 
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

lasso_aic = make_pipeline(StandardScaler(), LassoLarsIC(criterion="aic")).fit(X, y)

results_aic = pd.DataFrame(
    {
        "alphas": lasso_aic[-1].alphas_,
        "AIC criterion": lasso_aic[-1].criterion_,
    }
).set_index("alphas")
alpha_aic = lasso_aic[-1].alpha_

def highlight_min(x):
    x_min = x.min()
    return ["font-weight: bold" if v == x_min else "" for v in x]

results_aic.style.apply(highlight_min)
# Out:
# <style type="text/css">
# #T_64290_row15_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_64290">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64290_level0_col0" class="col_heading level0 col0" >AIC criterion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >alphas</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64290_level0_row0" class="row_heading level0 row0" >73.418559</th>
#       <td id="T_64290_row0_col0" class="data row0 col0" >232713.783397</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row1" class="row_heading level0 row1" >71.167932</th>
#       <td id="T_64290_row1_col0" class="data row1 col0" >232431.197613</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row2" class="row_heading level0 row2" >52.829253</th>
#       <td id="T_64290_row2_col0" class="data row2 col0" >228936.959756</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row3" class="row_heading level0 row3" >43.894148</th>
#       <td id="T_64290_row3_col0" class="data row3 col0" >227213.852207</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row4" class="row_heading level0 row4" >37.455257</th>
#       <td id="T_64290_row4_col0" class="data row4 col0" >225791.878977</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row5" class="row_heading level0 row5" >22.283241</th>
#       <td id="T_64290_row5_col0" class="data row5 col0" >223307.061380</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row6" class="row_heading level0 row6" >16.244149</th>
#       <td id="T_64290_row6_col0" class="data row6 col0" >222544.986824</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row7" class="row_heading level0 row7" >5.209619</th>
#       <td id="T_64290_row7_col0" class="data row7 col0" >221548.974715</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row8" class="row_heading level0 row8" >4.636335</th>
#       <td id="T_64290_row8_col0" class="data row8 col0" >221512.762552</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row9" class="row_heading level0 row9" >4.204503</th>
#       <td id="T_64290_row9_col0" class="data row9 col0" >221485.449401</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row10" class="row_heading level0 row10" >4.003730</th>
#       <td id="T_64290_row10_col0" class="data row10 col0" >221473.619041</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row11" class="row_heading level0 row11" >2.994465</th>
#       <td id="T_64290_row11_col0" class="data row11 col0" >221413.312643</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row12" class="row_heading level0 row12" >1.867123</th>
#       <td id="T_64290_row12_col0" class="data row12 col0" >221363.114579</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row13" class="row_heading level0 row13" >1.677993</th>
#       <td id="T_64290_row13_col0" class="data row13 col0" >221356.416584</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row14" class="row_heading level0 row14" >1.654482</th>
#       <td id="T_64290_row14_col0" class="data row14 col0" >221355.705273</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row15" class="row_heading level0 row15" >0.406325</th>
#       <td id="T_64290_row15_col0" class="data row15 col0" >221331.942561</td>
#     </tr>
#     <tr>
#       <th id="T_64290_level0_row16" class="row_heading level0 row16" >0.000000</th>
#       <td id="T_64290_row16_col0" class="data row16 col0" >221332.181105</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Optimizing lasso hyperparameter through cv
from sklearn.linear_model import LassoCV
alphac = np.linspace(0, 2, 5)
lasso_cv = make_pipeline(StandardScaler(), LassoCV(alphas=alphac, cv=10, random_state=1)).fit(X, y)
lasso = lasso_cv[-1]
plt.semilogx(lasso.alphas_, lasso.mse_path_, linestyle=":")
plt.plot(
    lasso.alphas_,
    lasso.mse_path_.mean(axis=-1),
    color="black",
    label="Average across the folds",
    linewidth=2,
)
plt.axvline(lasso.alpha_, linestyle="--", color="black", label="alpha: CV estimate")

plt.xlabel(r"$\alpha$")
plt.ylabel("Mean squared error")
plt.legend()
_ = plt.title(
    f"Mean squared error on each fold"
)

results_cv = pd.DataFrame(
    {
        "alphas": lasso_cv[-1].alphas_,
        "MSE": lasso_cv[-1].mse_path_.mean(axis=-1),
    }
).set_index("alphas")
alpha_cv = lasso_cv[-1].alpha_

def highlight_min(x):
    x_min = x.min()
    return ["font-weight: bold" if v == x_min else "" for v in x]

results_cv.style.apply(highlight_min)
# Out:
# <style type="text/css">
# #T_d3e02_row1_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d3e02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3e02_level0_col0" class="col_heading level0 col0" >MSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >alphas</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3e02_level0_row0" class="row_heading level0 row0" >2.000000</th>
#       <td id="T_d3e02_row0_col0" class="data row0 col0" >20662.036469</td>
#     </tr>
#     <tr>
#       <th id="T_d3e02_level0_row1" class="row_heading level0 row1" >1.500000</th>
#       <td id="T_d3e02_row1_col0" class="data row1 col0" >20657.136987</td>
#     </tr>
#     <tr>
#       <th id="T_d3e02_level0_row2" class="row_heading level0 row2" >1.000000</th>
#       <td id="T_d3e02_row2_col0" class="data row2 col0" >20661.508630</td>
#     </tr>
#     <tr>
#       <th id="T_d3e02_level0_row3" class="row_heading level0 row3" >0.500000</th>
#       <td id="T_d3e02_row3_col0" class="data row3 col0" >20674.532033</td>
#     </tr>
#     <tr>
#       <th id="T_d3e02_level0_row4" class="row_heading level0 row4" >0.000000</th>
#       <td id="T_d3e02_row4_col0" class="data row4 col0" >20719.291808</td>
#     </tr>
#   </tbody>
# </table>
